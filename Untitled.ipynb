# %%
import Gadget2Snapshot
import calculator

galaxy = Gadget2Snapshot.Gadget2Snapshot.open('examples/galaxy_littleendian.dat')
galaxy.readSnapshot()
# Out:
#  Done reading
# ERROR! Session/line number was not unique in database. History logging moved to new session 579
# Done reading (mass)
# Done reading

# %%
import numpy as np
np.savetxt('pos_galaxy_littleendian', galaxy.positions)
np.savetxt('pmass_galaxy_littleendian', galaxy.mass)

# %%
epsilon = 1.85
calculator.potential_bf(epsilon, galaxy.mass, galaxy.positions, -1)
# Out:
# Done reading
# Done reading (mass)
# Done reading
# 0 120.001144409
# 1 119.45539093
# 2 116.187744141
# 3 130.887191772
# 4 115.113098145
# 5 115.717987061
# 6 147.449295044
# 7 131.563583374
# 8 140.021850586
# 9 129.629852295
# 10 138.18409729
# 11 145.827896118
# 12 117.892799377
# 13 153.998779297
# 14 134.470397949
# 15 123.610908508
# 16 117.861450195
# 17 157.201797485
# 18 114.518569946
# 19 128.940826416
# 20 114.574104309
# 21 119.769248962
# 22 134.870758057
# 23 120.484428406
# 24 110.517272949
# 25 118.579284668
# 26 143.226165771
# 27 112.792304993
# 28 145.234176636
# 29 120.496444702
# 30 156.797317505
# 31 139.677429199
# 32 184.474975586
# 33 133.261291504
# 34 151.285400391
# 35 172.060348511
# 36 118.809501648
# 37 121.061828613
# 38 137.238052368
# 39 114.560203552
# 40 141.154678345
# 41 154.674194336
# 42 117.678565979
# 43 170.595092773
# 44 114.235832214
# 45 127.781669617
# 46 116.269630432
# 47 149.763244629
# 48 120.128860474
# 49 115.274940491
# ...
